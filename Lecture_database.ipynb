# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/68501079-0695df00-023c-11ea-841f-455dac84a089.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Reading data from relational databases
#
# In this lesson you will learn how to read SQL queries and relational database tables into `DataFrame` objects using pandas. Also, we'll take a look at different techniques to persist that pandas `DataFrame` objects to database tables.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (2.0.31)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (3.0.3)

# %%
import pandas as pd

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Read data from SQL database
#
# Reading data from SQL relational databases is fairly simple and pandas support a variety of methods to deal with it.
#
# We'll start with an example using SQLite, as it's a builtin Python package, and we don't need anything extra installed.

# %%
import sqlite3

# %% [markdown]
# In order to work with a SQLite database from Python, we first have to connect to it. We can do that using the connect function, which returns a `Connection` object.
#
# We'll use [this example database](http://www.sqlitetutorial.net/sqlite-sample-database/).

# %%
conn = sqlite3.connect('/content/drive/MyDrive/Colab_Datasets/chinook.db')
conn

# %% [markdown]
# Once we have a `Connection` object, we can then create a `Cursor` object. Cursors allow us to execute SQL queries against a database:

# %%
cur = conn.cursor()

# %% [markdown]
# The `Cursor` created has a method `execute`, which will receive SQL parameters to run against the database.
#
# The code below will fetch the first `5` rows from the `employees` table:

# %%
cur.execute('SELECT * FROM employees LIMIT 8;')

# %% [markdown]
# You may have noticed that we didn't assign the result of the above query to a variable. This is because we need to run another command to actually fetch the results.
#
# We can use the `fetchall` method to fetch all of the results of a query:

# %%
results = cur.fetchall()

# %%
results
# Out:
# [(1,
#   'Adams',
#   'Andrew',
#   'General Manager',
#   None,
#   '1962-02-18 00:00:00',
#   '2002-08-14 00:00:00',
#   '11120 Jasper Ave NW',
#   'Edmonton',
#   'AB',
#   'Canada',
#   'T5K 2N1',
#   '+1 (780) 428-9482',
#   '+1 (780) 428-3457',
#   'andrew@chinookcorp.com'),
#  (2,
#   'Edwards',
#   'Nancy',
#   'Sales Manager',
#   1,
#   '1958-12-08 00:00:00',
#   '2002-05-01 00:00:00',
#   '825 8 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 2T3',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-3322',
#   'nancy@chinookcorp.com'),
#  (3,
#   'Peacock',
#   'Jane',
#   'Sales Support Agent',
#   2,
#   '1973-08-29 00:00:00',
#   '2002-04-01 00:00:00',
#   '1111 6 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5M5',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-6712',
#   'jane@chinookcorp.com'),
#  (4,
#   'Park',
#   'Margaret',
#   'Sales Support Agent',
#   2,
#   '1947-09-19 00:00:00',
#   '2003-05-03 00:00:00',
#   '683 10 Street SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5G3',
#   '+1 (403) 263-4423',
#   '+1 (403) 263-4289',
#   'margaret@chinookcorp.com'),
#  (5,
#   'Johnson',
#   'Steve',
#   'Sales Support Agent',
#   2,
#   '1965-03-03 00:00:00',
#   '2003-10-17 00:00:00',
#   '7727B 41 Ave',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T3B 1Y7',
#   '1 (780) 836-9987',
#   '1 (780) 836-9543',
#   'steve@chinookcorp.com'),
#  (6,
#   'Mitchell',
#   'Michael',
#   'IT Manager',
#   1,
#   '1973-07-01 00:00:00',
#   '2003-10-17 00:00:00',
#   '5827 Bowness Road NW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T3B 0C5',
#   '+1 (403) 246-9887',
#   '+1 (403) 246-9899',
#   'michael@chinookcorp.com'),
#  (7,
#   'King',
#   'Robert',
#   'IT Staff',
#   6,
#   '1970-05-29 00:00:00',
#   '2004-01-02 00:00:00',
#   '590 Columbia Boulevard West',
#   'Lethbridge',
#   'AB',
#   'Canada',
#   'T1K 5N8',
#   '+1 (403) 456-9986',
#   '+1 (403) 456-8485',
#   'robert@chinookcorp.com'),
#  (8,
#   'Callahan',
#   'Laura',
#   'IT Staff',
#   6,
#   '1968-01-09 00:00:00',
#   '2004-03-04 00:00:00',
#   '923 7 ST NW',
#   'Lethbridge',
#   'AB',
#   'Canada',
#   'T1H 1Y8',
#   '+1 (403) 467-3351',
#   '+1 (403) 467-8772',
#   'laura@chinookcorp.com')]

# %% [markdown]
# As you can see, the results are returned as a list of tuples. Each tuple corresponds to a row in the database that we accessed. Dealing with data this way is painful.
#
# We'd need to manually add column headers, and manually parse the data. Luckily, the pandas library has an easier way, which we'll look at in the next section.

# %%
df = pd.DataFrame(results)
# df = df.set_index(0)
df
# Out:
#    0         1         2                    3    4                    5   \
# 0   1     Adams    Andrew      General Manager  NaN  1962-02-18 00:00:00
# 1   2   Edwards     Nancy        Sales Manager  1.0  1958-12-08 00:00:00
# 2   3   Peacock      Jane  Sales Support Agent  2.0  1973-08-29 00:00:00
# 3   4      Park  Margaret  Sales Support Agent  2.0  1947-09-19 00:00:00
# 4   5   Johnson     Steve  Sales Support Agent  2.0  1965-03-03 00:00:00
# 5   6  Mitchell   Michael           IT Manager  1.0  1973-07-01 00:00:00
# 6   7      King    Robert             IT Staff  6.0  1970-05-29 00:00:00
# 7   8  Callahan     Laura             IT Staff  6.0  1968-01-09 00:00:00
#
#                     6                            7           8   9       10  \
# 0  2002-08-14 00:00:00          11120 Jasper Ave NW    Edmonton  AB  Canada
# 1  2002-05-01 00:00:00                 825 8 Ave SW     Calgary  AB  Canada
# 2  2002-04-01 00:00:00                1111 6 Ave SW     Calgary  AB  Canada
# 3  2003-05-03 00:00:00             683 10 Street SW     Calgary  AB  Canada
# 4  2003-10-17 00:00:00                 7727B 41 Ave     Calgary  AB  Canada
# 5  2003-10-17 00:00:00         5827 Bowness Road NW     Calgary  AB  Canada
# 6  2004-01-02 00:00:00  590 Columbia Boulevard West  Lethbridge  AB  Canada
# 7  2004-03-04 00:00:00                  923 7 ST NW  Lethbridge  AB  Canada
#
#         11                 12                 13                        14
# 0  T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 3  T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 4  T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com
# 5  T3B 0C5  +1 (403) 246-9887  +1 (403) 246-9899   michael@chinookcorp.com
# 6  T1K 5N8  +1 (403) 456-9986  +1 (403) 456-8485    robert@chinookcorp.com
# 7  T1H 1Y8  +1 (403) 467-3351  +1 (403) 467-8772     laura@chinookcorp.com

# %%
# df.drop(columns = 0, inplace = True)
df
# Out:
#    0         1         2                    3    4                    5   \
# 0   1     Adams    Andrew      General Manager  NaN  1962-02-18 00:00:00
# 1   2   Edwards     Nancy        Sales Manager  1.0  1958-12-08 00:00:00
# 2   3   Peacock      Jane  Sales Support Agent  2.0  1973-08-29 00:00:00
# 3   4      Park  Margaret  Sales Support Agent  2.0  1947-09-19 00:00:00
# 4   5   Johnson     Steve  Sales Support Agent  2.0  1965-03-03 00:00:00
# 5   6  Mitchell   Michael           IT Manager  1.0  1973-07-01 00:00:00
# 6   7      King    Robert             IT Staff  6.0  1970-05-29 00:00:00
# 7   8  Callahan     Laura             IT Staff  6.0  1968-01-09 00:00:00
#
#                     6                            7           8   9       10  \
# 0  2002-08-14 00:00:00          11120 Jasper Ave NW    Edmonton  AB  Canada
# 1  2002-05-01 00:00:00                 825 8 Ave SW     Calgary  AB  Canada
# 2  2002-04-01 00:00:00                1111 6 Ave SW     Calgary  AB  Canada
# 3  2003-05-03 00:00:00             683 10 Street SW     Calgary  AB  Canada
# 4  2003-10-17 00:00:00                 7727B 41 Ave     Calgary  AB  Canada
# 5  2003-10-17 00:00:00         5827 Bowness Road NW     Calgary  AB  Canada
# 6  2004-01-02 00:00:00  590 Columbia Boulevard West  Lethbridge  AB  Canada
# 7  2004-03-04 00:00:00                  923 7 ST NW  Lethbridge  AB  Canada
#
#         11                 12                 13                        14
# 0  T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 3  T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 4  T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com
# 5  T3B 0C5  +1 (403) 246-9887  +1 (403) 246-9899   michael@chinookcorp.com
# 6  T1K 5N8  +1 (403) 456-9986  +1 (403) 456-8485    robert@chinookcorp.com
# 7  T1H 1Y8  +1 (403) 467-3351  +1 (403) 467-8772     laura@chinookcorp.com

# %%
df.columns = ['EmployeeId', 'LastName', 'FirstName', 'Title', 'ReportsTo', 'BirthDate', 'HireDate', 'Address', 'City', 'State/Provience', 'Country', 'PostalCode', 'Phone', 'Fax', 'Email']

df
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00                 7727B 41 Ave
# 5  1973-07-01 00:00:00  2003-10-17 00:00:00         5827 Bowness Road NW
# 6  1970-05-29 00:00:00  2004-01-02 00:00:00  590 Columbia Boulevard West
# 7  1968-01-09 00:00:00  2004-03-04 00:00:00                  923 7 ST NW
#
#          City State/Provience Country PostalCode              Phone  \
# 0    Edmonton              AB  Canada    T5K 2N1  +1 (780) 428-9482
# 1     Calgary              AB  Canada    T2P 2T3  +1 (403) 262-3443
# 2     Calgary              AB  Canada    T2P 5M5  +1 (403) 262-3443
# 3     Calgary              AB  Canada    T2P 5G3  +1 (403) 263-4423
# 4     Calgary              AB  Canada    T3B 1Y7   1 (780) 836-9987
# 5     Calgary              AB  Canada    T3B 0C5  +1 (403) 246-9887
# 6  Lethbridge              AB  Canada    T1K 5N8  +1 (403) 456-9986
# 7  Lethbridge              AB  Canada    T1H 1Y8  +1 (403) 467-3351
#
#                  Fax                     Email
# 0  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  +1 (403) 262-6712      jane@chinookcorp.com
# 3  +1 (403) 263-4289  margaret@chinookcorp.com
# 4   1 (780) 836-9543     steve@chinookcorp.com
# 5  +1 (403) 246-9899   michael@chinookcorp.com
# 6  +1 (403) 456-8485    robert@chinookcorp.com
# 7  +1 (403) 467-8772     laura@chinookcorp.com

# %%
df['BirthDate'] = pd.to_datetime(df['BirthDate'])
df['HireDate'] = pd.to_datetime(df['HireDate'])
df
# Out:
#             LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1              Adams    Andrew      General Manager        NaN 1962-02-18
# 2            Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3            Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4               Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5            Johnson     Steve  Sales Support Agent        2.0 1965-03-03
# 6           Mitchell   Michael           IT Manager        1.0 1973-07-01
# 7               King    Robert             IT Staff        6.0 1970-05-29
# 8           Callahan     Laura             IT Staff        6.0 1968-01-09
#
#              HireDate                      Address        City  \
# EmployeeId
# 1          2002-08-14          11120 Jasper Ave NW    Edmonton
# 2          2002-05-01                 825 8 Ave SW     Calgary
# 3          2002-04-01                1111 6 Ave SW     Calgary
# 4          2003-05-03             683 10 Street SW     Calgary
# 5          2003-10-17                 7727B 41 Ave     Calgary
# 6          2003-10-17         5827 Bowness Road NW     Calgary
# 7          2004-01-02  590 Columbia Boulevard West  Lethbridge
# 8          2004-03-04                  923 7 ST NW  Lethbridge
#
#            State/Provience Country PostalCode              Phone  \
# EmployeeId
# 1                       AB  Canada    T5K 2N1  +1 (780) 428-9482
# 2                       AB  Canada    T2P 2T3  +1 (403) 262-3443
# 3                       AB  Canada    T2P 5M5  +1 (403) 262-3443
# 4                       AB  Canada    T2P 5G3  +1 (403) 263-4423
# 5                       AB  Canada    T3B 1Y7   1 (780) 836-9987
# 6                       AB  Canada    T3B 0C5  +1 (403) 246-9887
# 7                       AB  Canada    T1K 5N8  +1 (403) 456-9986
# 8                       AB  Canada    T1H 1Y8  +1 (403) 467-3351
#
#                           Fax                     Email
# EmployeeId
# 1           +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9543     steve@chinookcorp.com
# 6           +1 (403) 246-9899   michael@chinookcorp.com
# 7           +1 (403) 456-8485    robert@chinookcorp.com
# 8           +1 (403) 467-8772     laura@chinookcorp.com

# %%
df.set_index('EmployeeId',inplace = True)
df
# Out:
#             LastName FirstName                Title  ReportsTo  \
# EmployeeId
# 1              Adams    Andrew      General Manager        NaN
# 2            Edwards     Nancy        Sales Manager        1.0
# 3            Peacock      Jane  Sales Support Agent        2.0
# 4               Park  Margaret  Sales Support Agent        2.0
# 5            Johnson     Steve  Sales Support Agent        2.0
# 6           Mitchell   Michael           IT Manager        1.0
# 7               King    Robert             IT Staff        6.0
# 8           Callahan     Laura             IT Staff        6.0
#
#                       BirthDate             HireDate  \
# EmployeeId
# 1           1962-02-18 00:00:00  2002-08-14 00:00:00
# 2           1958-12-08 00:00:00  2002-05-01 00:00:00
# 3           1973-08-29 00:00:00  2002-04-01 00:00:00
# 4           1947-09-19 00:00:00  2003-05-03 00:00:00
# 5           1965-03-03 00:00:00  2003-10-17 00:00:00
# 6           1973-07-01 00:00:00  2003-10-17 00:00:00
# 7           1970-05-29 00:00:00  2004-01-02 00:00:00
# 8           1968-01-09 00:00:00  2004-03-04 00:00:00
#
#                                 Address        City State/Provience Country  \
# EmployeeId
# 1                   11120 Jasper Ave NW    Edmonton              AB  Canada
# 2                          825 8 Ave SW     Calgary              AB  Canada
# 3                         1111 6 Ave SW     Calgary              AB  Canada
# 4                      683 10 Street SW     Calgary              AB  Canada
# 5                          7727B 41 Ave     Calgary              AB  Canada
# 6                  5827 Bowness Road NW     Calgary              AB  Canada
# 7           590 Columbia Boulevard West  Lethbridge              AB  Canada
# 8                           923 7 ST NW  Lethbridge              AB  Canada
#
#            PostalCode              Phone                Fax  \
# EmployeeId
# 1             T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 2             T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 3             T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 4             T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 5             T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 6             T3B 0C5  +1 (403) 246-9887  +1 (403) 246-9899
# 7             T1K 5N8  +1 (403) 456-9986  +1 (403) 456-8485
# 8             T1H 1Y8  +1 (403) 467-3351  +1 (403) 467-8772
#
#                                Email
# EmployeeId
# 1             andrew@chinookcorp.com
# 2              nancy@chinookcorp.com
# 3               jane@chinookcorp.com
# 4           margaret@chinookcorp.com
# 5              steve@chinookcorp.com
# 6            michael@chinookcorp.com
# 7             robert@chinookcorp.com
# 8              laura@chinookcorp.com

# %% [markdown]
# Before we move on, it's good practice to close `Connection` objects and `Cursor` objects that are open. This prevents the SQLite database from being locked. When a SQLite database is locked, you may be unable to update the database, and may get errors. We can close the Cursor and the Connection like this:

# %%
cur.close()
conn.close()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Using pandas `read_sql` method
#
# We can use the pandas `read_sql` function to read the results of a SQL query directly into a pandas `DataFrame`. The code below will execute the same query that we just did, but it will return a `DataFrame`. It has several advantages over the query we did above:
#
# - It doesn't require us to create a `Cursor` object or call `fetchall` at the end.
# - It automatically reads in the names of the headers from the table.
# - It creates a `DataFrame`, so we can quickly explore the data.

# %%
conn = sqlite3.connect('/content/drive/MyDrive/Colab_Datasets/chinook.db')

# %%
df = pd.read_sql('SELECT * FROM employees;', conn)

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
df = pd.read_sql('SELECT * FROM employees;', conn,
                 index_col='EmployeeId',
                 parse_dates=['BirthDate', 'HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 1 to 8
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LastName    8 non-null      object
#  1   FirstName   8 non-null      object
#  2   Title       8 non-null      object
#  3   ReportsTo   7 non-null      float64
#  4   BirthDate   8 non-null      datetime64[ns]
#  5   HireDate    8 non-null      datetime64[ns]
#  6   Address     8 non-null      object
#  7   City        8 non-null      object
#  8   State       8 non-null      object
#  9   Country     8 non-null      object
#  10  PostalCode  8 non-null      object
#  11  Phone       8 non-null      object
#  12  Fax         8 non-null      object
#  13  Email       8 non-null      object
# dtypes: datetime64[ns](2), float64(1), object(11)
# memory usage: 960.0+ bytes

# %%
df['ReportsTo'].isna().sum()
# Out:
# 1

# %%
df['ReportsTo'].mean()
# Out:
# 2.857142857142857

# %%
df['ReportsTo'] > 1.75
# Out:
# EmployeeId
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# Name: ReportsTo, dtype: bool

# %%
df['City'] = df['City'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 1 to 8
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LastName    8 non-null      object
#  1   FirstName   8 non-null      object
#  2   Title       8 non-null      object
#  3   ReportsTo   7 non-null      float64
#  4   BirthDate   8 non-null      datetime64[ns]
#  5   HireDate    8 non-null      datetime64[ns]
#  6   Address     8 non-null      object
#  7   City        8 non-null      category
#  8   State       8 non-null      object
#  9   Country     8 non-null      object
#  10  PostalCode  8 non-null      object
#  11  Phone       8 non-null      object
#  12  Fax         8 non-null      object
#  13  Email       8 non-null      object
# dtypes: category(1), datetime64[ns](2), float64(1), object(10)
# memory usage: 1.0+ KB

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Using pandas `read_sql_query` method
#
# It turns out that the `read_sql` method we saw above is just a wrapper around `read_sql_query` and `read_sql_table`.
#
# We can get the same result using `read_sql_query` method:

# %%
conn = sqlite3.connect('/content/drive/MyDrive/Colab_Datasets/chinook.db')

# %%
df = pd.read_sql_query('SELECT * FROM employees LIMIT 5;', conn)

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
df = pd.read_sql_query('SELECT * FROM employees;', conn,
                       index_col='EmployeeId',
                       parse_dates=['BirthDate', 'HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Using `read_sql_table` method
#
# `read_sql_table` is a useful function, but it works only with [SQLAlchemy](https://www.sqlalchemy.org/), a Python SQL Toolkit and Object Relational Mapper.
#
# This is just a demonstration of its usage where we read the whole `employees` table.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:////content/drive/MyDrive/Colab_Datasets/chinook.db')

connection = engine.connect()

# %%
# # Update the path to reflect the actual location of your database file in Google Drive
# db_path = '/content/drive/MyDrive/Colab_Datasets/chinook.db'

# engine = create_engine(f'sqlite:///{db_path}')

# # Verify the connection
# try:
#     connection = engine.connect()
#     print("Connection successful!")
# except Exception as e:
#     print("Connection failed:", e)

# # # Now you should be able to read the data
# # df = pd.read_sql_query('SELECT * FROM employees;', connection,
# #                        index_col='EmployeeId',
# #                        parse_dates=['BirthDate', 'HireDate'])

# # df.head()

# %%
df = pd.read_sql_table('employees', con=connection)

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew      General Manager        NaN 1962-02-18
# 1           2  Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 2           3  Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 3           4     Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 4           5  Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#     HireDate              Address      City State Country PostalCode  \
# 0 2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1 2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 2 2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 3 2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 4 2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# 0  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 3  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 4   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
df = pd.read_sql_table('employees', con=connection,
                       index_col='EmployeeId',
                       parse_dates=['BirthDate', 'HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
connection.close()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Create tables from `DataFrame` objects
#
# Finally we can persist `DataFrame` objects we've working on in a database using the pandas `to_sql` method.
#
# Although it is easy to implement, it could be a very slow process.

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
df.to_sql('employees2', conn)
# Out:
# 8

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
# pd.read_sql_query('DROP TABLE employees2;', conn)

# %% [markdown]
# ## Custom behaviour
#
# The `if_exists` parameter define how to behave if the table already exists and adds a ton of flexibility, letting you decide wheather to `replace` current database data, `append` new data at the end, or simply `fail` if database already exists.

# %%
pd.DataFrame().to_sql('employees2',
                      conn,
                      if_exists='replace')
# Out:
# 0

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
# Empty DataFrame
# Columns: [index]
# Index: []

# %%
df.to_sql('employees2',
          conn,
          if_exists='replace')
# Out:
# 8

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
conn.close()

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
